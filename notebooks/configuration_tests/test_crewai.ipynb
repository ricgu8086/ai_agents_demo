# %%
import os

from crewai import LLM
from dotenv import load_dotenv

# %%
# OpenRouter configuration

""""
More info here:
https://openrouter.ai/docs/quickstart
https://docs.crewai.com/v1.15.22/en/concepts/llms#open-router
"""

SELECTED_MODEL="deepseek/deepseek-v4-flash-0731"
URL_PROVIDER="https://openrouter.ai/api/v1/chat/completions"

# %%
load_dotenv(override=True)
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")

# %%
def get_llm():
    return LLM(model=SELECTED_MODEL, 
               api_key=API_KEY, 
               base_url=URL_PROVIDER
               )

# "reasoning_effort"="none"

# %%
llm = get_llm()

# %%
response = llm.call("Tell me something about Pacman")
print(response)
# Out:
# Pac-Man is one of the most iconic video games ever created, released in 1980 by Namco (designed by Toru Iwatani).
#
# - **Gameplay:** The player controls Pac-Man, a yellow circle with a mouth, navigating a maze while eating dots. The goal is to clear all dots while avoiding four ghosts: Blinky, Pinky, Inky, and Clyde.
# - **Power Pellets:** Larger flashing dots let Pac-Man temporarily turn the tables and eat the ghosts for bonus points.
# - **Origin:** Iwatani wanted to create a game that appealed to women and was less violent than the space shooters popular at the time. The design was inspired by a pizza with a slice missing.
# - **Cultural Impact:** It became a pop-culture phenomenon, spawning merchandise, an animated TV show, hit song “Pac-Man Fever,” and countless sequels. It also introduced the concept of video game mascots and helped popularize arcade gaming worldwide.
# - **Legacy:** Pac-Man remains a beloved symbol of retro gaming and still appears in new games, movies, and memes today.
